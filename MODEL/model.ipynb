# %% [markdown]
# Visualization, Analysis and Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../DATA PREPARATION/cleaned_data_above60.csv")
df_coded = pd.read_csv("../DATA PREPARATION/coded_data.csv")

# %% [markdown]
# 2011-2015

# %% [markdown]
# Age Distribution

# %%
plt.title("Age Distribution Accross Population (2011-2015)")
plt.ylabel("frequency")
plt.xlabel("age")
df.age_cal.hist()
# Out:
# <Axes: title={'center': 'Age Distribution Accross Population (2011-2015)'}, xlabel='age', ylabel='frequency'>

# %%
plt.title("Age Distribution Accross Population 2011")
plt.ylabel("frequency")
plt.xlabel("age")
df_2011 = df[df["Year"]==2011]
df_2011.age_cal.hist()
# Out:
# <Axes: title={'center': 'Age Distribution Accross Population 2011'}, xlabel='age', ylabel='frequency'>

# %%
plt.title("Age Distribution Accross Population 2013")
plt.ylabel("frequency")
plt.xlabel("age")
df_2011 = df[df["Year"]==2013]
df_2011.age_cal.hist()
# Out:
# <Axes: title={'center': 'Age Distribution Accross Population 2013'}, xlabel='age', ylabel='frequency'>

# %%
plt.title("Age Distribution Accross Population 2015")
plt.ylabel("frequency")
plt.xlabel("age")
df_2011 = df[df["Year"]==2015]
df_2011.age_cal.hist()
# Out:
# <Axes: title={'center': 'Age Distribution Accross Population 2015'}, xlabel='age', ylabel='frequency'>

# %%
# %matplotlib inline
pd.crosstab(df.communityID, [df.liver_dis]).plot(kind='bar', )
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.communityID, [df.hyp]).plot(kind='bar', )
plt.show()

# %%
df.main_toilet_type.value_counts()
# Out:
# Inside toilet with water               277
# Open-air                               151
# Outside public toilet without water    139
# Outside toilet with water               30
# Inside toilet without water             24
# Name: main_toilet_type, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Step 2: Plot the countplot for 'cancer' for each 'community_id'
plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
sns.countplot(data=df, x='communityID', hue='self_com_on_health', palette='muted')

plt.xlabel('Community ID')
plt.ylabel('Count')
plt.title('Countplot of Health Status in Each Community')
plt.legend(title='Health status', loc='upper right')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.communityID, [df.stomach_dis]).plot(kind='bar', )
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.communityID, [df.lung_dis]).plot(kind='bar', )
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.communityID, [df.rheumatism]).plot(kind='bar', )
plt.show()

# %%
# %matplotlib inline
pd.crosstab(df.communityID, [df.mem_rel_dis]).plot(kind='bar', )
plt.show()

# %% [markdown]
# 2011

# %%
data =df

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Filter data for the year 2011
data_2011 = data[data['Year'] == 2011]

# Step 2: Plot the countplot for 'cancer' for each 'community_id'
plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
sns.countplot(data=data_2011, x='communityID', hue='liver_dis', palette='muted')

plt.xlabel('Community ID')
plt.ylabel('Count')
plt.title('Countplot of Liver Response in Each Community (Year 2011)')
plt.legend(title='Liver', loc='upper right')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Filter data for the year 2011
# data_2011 = data[data['Year'] == 2011]

# Step 2: Plot the countplot for 'cancer' for each 'community_id'
plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
sns.countplot(data=df, x='communityID', hue='cooking_fuel_source', palette='muted')
plt.xlabel('Community ID')
plt.ylabel('Count')
plt.title('Countplot of Cooking Fuel Source Response in Each Community (2011-2015)')
plt.legend(title='Cooking Fuel Source', loc='upper right')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Filter data for the year 2011
data_2011 = data[data['Year'] == 2011]

# Step 2: Plot the countplot for 'cancer' for each 'community_id'
plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
sns.countplot(data=data_2011, x='communityID', hue='road_type', palette='muted')

plt.xlabel('Community ID')
plt.ylabel('Count')
plt.title('Countplot of road_type Response in Each Community (Year 2011)')
plt.legend(title='road_type', loc='upper right')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Step 2: Plot the countplot for 'cancer' for each 'community_id'
plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
sns.countplot(data=df, x='communityID', hue='main_toilet_type', palette='muted')

plt.xlabel('Community ID')
plt.ylabel('Count')
plt.title('Countplot of Main Toilet Types Response in Each Community 2011 - 2015')
plt.legend(title='main Toilet Type', loc='upper right')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Step 2: Plot the countplot for 'cancer' for each 'community_id'
plt.figure(figsize=(12, 6))  # Adjust the figure size if needed
sns.countplot(data=df, x='communityID', hue='hyp', palette='muted')

plt.xlabel('Community ID')
plt.ylabel('Count')
plt.title('Countplot of Hypertension Response in Each Community 2011 - 2015')
plt.legend(title='Hypertension', loc='upper right')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# Checking Correlation on Data set

# %% [markdown]
# Chi-Square Between Variables

# %%
import scipy.stats as stats 
from scipy.stats import chi2_contingency

variab = ['hyp','mem_rel_dis', 'rheumatism', 'lung_dis','liver_dis', 'stomach_dis', 'self_com_on_health']

variables = ['communityID', 'province', 'city', 'urban_nbs', 'age_cal', 'has_running_water', 'inhouse_shower_Bath','cooking_fuel_source', 'hyp', 'mem_rel_dis', 'self_com_on_health', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'main_toilet_type', 'sewage_sys', 'waste_management', 'road_type']
for  var in variab:
    crosstab = pd.crosstab(data['cooking_fuel_source'], data[var])
    chisquare, p_value, dof, exv = chi2_contingency(crosstab)
#     print(crosstab)
    print("--------------------------------")
    print(f'chisquare between cooking_fuel_source and ',var)
    print(f'chisquare:',chisquare, 
          'p_value: ',p_value, 
          'dof:',dof, 
          'expected value:', exv)
    print("---------------------------------")
# Out:
# --------------------------------
# chisquare between cooking_fuel_source and  hyp
# chisquare: 18.10075695202955 p_value:  0.00282274309085314 dof: 5 expected value: [[ 40.19323671  23.80676329]
#  [ 83.52657005  49.47342995]
#  [ 87.29468599  51.70531401]
#  [ 33.28502415  19.71497585]
#  [  1.88405797   1.11594203]
#  [143.81642512  85.18357488]]
# ---------------------------------
# --------------------------------
# chisquare between cooking_fuel_source and  mem_rel_dis
# chisquare: 7.611696440672302 p_value:  0.17897420071293202 dof: 5 expected value: [[6.14235105e+01 2.57648953e+00]
#  [1.27645733e+02 5.35426731e+00]
#  [1.33404187e+02 5.59581320e+00]
#  [5.08663446e+01 2.13365539e+00]
#  [2.87922705e+00 1.20772947e-01]
#  [2.19780998e+02 9.21900161e+00]]
# ---------------------------------
# --------------------------------
# chisquare between cooking_fuel_source and  rheumatism
# ...

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Your variable lists

variab = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
variables = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']

# Create an empty list to store the results
results = []

# Perform the chi-square tests and store the results
for var in variab:
    crosstab = pd.crosstab(data['inhouse_shower_Bath'], data[var])
    chisquare, p_value, dof, exv = chi2_contingency(crosstab)
    # Store the results in a dictionary
    result_dict = {
        'Independent Variable': 'inhouse_shower_Bath',
        'Target Variable': var,
        'Chi-Square': chisquare,
        'P-Value': p_value,
     
    }
    results.append(result_dict)

# Create a dataframe from the results list
result_df = pd.DataFrame(results)

# Print the dataframe
result_df
# result_df.to_csv("./cooking_fuel_source_results.csv")
# Out:
#   Independent Variable     Target Variable  Chi-Square   P-Value
# 0  inhouse_shower_Bath                 hyp    1.003220  0.605555
# 1  inhouse_shower_Bath         mem_rel_dis   15.863941  0.000359
# 2  inhouse_shower_Bath          rheumatism    3.413108  0.181490
# 3  inhouse_shower_Bath            lung_dis    4.323431  0.115127
# 4  inhouse_shower_Bath           liver_dis    1.787167  0.409187
# 5  inhouse_shower_Bath         stomach_dis    0.065592  0.967736
# 6  inhouse_shower_Bath  self_com_on_health   26.920474  0.000730

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you have loaded your dataset into a DataFrame named 'data'
# data = pd.read_csv('your_data.csv')

# Lists of health variables and sanitation variables
health_vars = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
sanitation_vars = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']

# Create an empty list to store the results
results = []

# Perform the chi-square tests and store the results
for sanitation_var in sanitation_vars:
    for health_var in health_vars:
        crosstab = pd.crosstab(data[sanitation_var], data[health_var])
        chisquare, p_value, dof, exv = chi2_contingency(crosstab)
        # Store the results in a dictionary
        result_dict = {
            'Sanitation Variable': sanitation_var,
            'Health Variable': health_var,
            'Chi-Square': chisquare,
            'P-Value': p_value,
        }
        results.append(result_dict)

# Create a DataFrame from the results list
result_df = pd.DataFrame(results)

# Print the DataFrame
result_df
result_df.to_csv("./chisquare_results.csv")

# %% [markdown]
# Pivot table function showing the correlation

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you have loaded your dataset into a DataFrame named 'data'
# data = pd.read_csv('your_data.csv')

# Lists of health variables and sanitation variables
health_vars = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
sanitation_vars = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']

# Create an empty list to store the results
results = []

# Perform the chi-square tests and store the results
for sanitation_var in sanitation_vars:
    for health_var in health_vars:
        crosstab = pd.crosstab(data[sanitation_var], data[health_var])
        chisquare, p_value, dof, exv = chi2_contingency(crosstab)
        # Store the results in a dictionary
        result_dict = {
            'Sanitation Variable': sanitation_var,
            'Health Variable': health_var,
            'P-Value': p_value,
        }
        results.append(result_dict)

# Create a DataFrame from the results list
result_df = pd.DataFrame(results)

# Create a pivot table to compare p-values between health and sanitation variables
pivot_table = result_df.pivot_table(index='Health Variable', columns='Sanitation Variable', values='P-Value')

# Print the pivot table
# pivot_table.to_csv("./pivot_table.csv",)
pivot_table
# Out:
# Sanitation Variable  cooking_fuel_source  has_running_water  \
# Health Variable
# hyp                             0.002823           0.258062
# liver_dis                       0.158573           0.028550
# lung_dis                        0.018068           0.889770
# mem_rel_dis                     0.178974           0.030393
# rheumatism                      0.000079           0.304168
# self_com_on_health              0.000002           0.032877
# stomach_dis                     0.016391           0.239683
#
# Sanitation Variable  inhouse_shower_Bath  main_toilet_type  road_type  \
# Health Variable
# hyp                             0.605555          0.005294   0.045904
# liver_dis                       0.409187          0.009797   0.000331
# lung_dis                        0.115127          0.196169   0.004616
# mem_rel_dis                     0.000359          0.417673   0.100856
# rheumatism                      0.181490          0.000076   0.064296
# ...

# %% [markdown]
# cramers_v

# %%
import numpy as np

def cramers_v(confusion_matrix):
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k - 1) * (r - 1)) / (n - 1))
    rcorr = r - ((r - 1) ** 2) / (n - 1)
    kcorr = k - ((k - 1) ** 2) / (n - 1)
    return np.sqrt(phi2corr / min((kcorr - 1), (rcorr - 1)))

# %% [markdown]
# For only variables with association

# %%
import pandas as pd
from scipy.stats import chi2_contingency
import seaborn as sns

# List of sanitation variables and health variables
health_vars = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
sanitation_vars = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']

# Loop through sanitation and health variables to calculate associations
for sanitation_var in sanitation_vars:
    for health_var in health_vars:
        contingency_table = pd.crosstab(data[sanitation_var], data[health_var])
        chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)
        
        # Check for significance based on p-value threshold (e.g., 0.05)
        if p_val < 0.05:
            cramer_v = cramers_v(contingency_table.values)
            print(f"Significant association between {sanitation_var} and {health_var}:")
            print("Chi-squared statistic:", chi2_stat)
            print("P-value:", p_val)
            print("Cramér's V:", cramer_v)
            print("\n")
            
            # # Visualization of associations using seaborn
            # plt.figure(figsize=(8, 6))
            # sns.heatmap(contingency_table, annot=True, fmt="d", cmap="YlGnBu")
            # plt.title(f"{sanitation_var} vs {health_var}")
            # plt.xlabel(health_var)
            # plt.ylabel(sanitation_var)
            # plt.show()
# Out:
# Significant association between has_running_water and mem_rel_dis:
# Chi-squared statistic: 4.6869228746937575
# P-value: 0.030393029206144784
# Cramér's V: 0.07709775485902712
#
#
# Significant association between has_running_water and liver_dis:
# Chi-squared statistic: 4.79455781764447
# P-value: 0.02854978407205652
# Cramér's V: 0.07821552916540143
#
#
# Significant association between has_running_water and self_com_on_health:
# Chi-squared statistic: 10.494189330746924
# P-value: 0.032877124623446295
# Cramér's V: 0.10229428290600313
#
#
# Significant association between inhouse_shower_Bath and mem_rel_dis:
# Chi-squared statistic: 15.863941034303766
# P-value: 0.000359078145688343
# Cramér's V: 0.14951939827757196
#
#
# Significant association between inhouse_shower_Bath and self_com_on_health:
# Chi-squared statistic: 26.92047432935515
# P-value: 0.0007296894475395799
# Cramér's V: 0.12358298487168526
#
#
# Significant association between cooking_fuel_source and hyp:
# ...

# %% [markdown]
# For only variables that has an association

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# List of sanitation variables and health variables
health_vars = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
sanitation_vars = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']

# Create an empty list to store results
results = []

# Loop through sanitation and health variables to calculate associations
for sanitation_var in sanitation_vars:
    for health_var in health_vars:
        contingency_table = pd.crosstab(data[sanitation_var], data[health_var])
        chi2_stat, p_val, dof, expected = chi2_contingency(contingency_table)
        
        # Check for significance based on p-value threshold (e.g., 0.05)
        if p_val < 0.05:
            cramer_v = cramers_v(contingency_table.values)
            result = {
                'Sanitation Variable': sanitation_var,
                'Health Variable': health_var,
                'Chi-squared Statistic': chi2_stat,
                'P-value': p_val,
                "Cramér's V": cramer_v
            }
            results.append(result)

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Display the results DataFrame
results_df.to_csv("./chisquare_results_cramers_for_as.csv")

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Load your dataset into a DataFrame
# data = pd.read_csv('data.csv')

# List of sanitation variables and health variables
health_vars = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
sanitation_vars = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']
# Create a dictionary to store aggregate Cramér's V values for each sanitation variable
aggregate_cramers = {}

# Loop through sanitation and health variables to calculate associations
for sanitation_var in sanitation_vars:
    aggregate_cramer = 0
    
    for health_var in health_vars:
        contingency_table = pd.crosstab(data[sanitation_var], data[health_var])
        cramer_v = cramers_v(contingency_table.values)
        aggregate_cramer += cramer_v
        
    # Calculate the mean Cramér's V across all health variables
    mean_cramer = aggregate_cramer / len(health_vars)
    
    # Store the mean Cramér's V in the dictionary
    aggregate_cramers[sanitation_var] = mean_cramer

# Display the mean Cramér's V values for all sanitation variables
for sanitation_var, mean_cramer in aggregate_cramers.items():
    print(f"Sanitation variable: {sanitation_var}")
    print(f"Mean Cramér's V: {mean_cramer:.4f}")
    print("=" * 20)

# Identify the sanitation variable with the highest mean Cramér's V
most_contributing_variable = max(aggregate_cramers, key=aggregate_cramers.get)

print("Most contributing sanitation variable to health variables combined:", most_contributing_variable)
print("Mean Cramér's V:", aggregate_cramers[most_contributing_variable])
# Out:
# Sanitation variable: has_running_water
# Mean Cramér's V: 0.0447
# ...
# Sanitation variable: inhouse_shower_Bath
# Mean Cramér's V: 0.0546
# ...
# Sanitation variable: cooking_fuel_source
# Mean Cramér's V: 0.1193
# ...
# Sanitation variable: main_toilet_type
# Mean Cramér's V: 0.0913
# ...
# Sanitation variable: sewage_sys
# Mean Cramér's V: 0.0740
# ...
# Sanitation variable: road_type
# Mean Cramér's V: 0.0818
# ...
# Sanitation variable: waste_management
# Mean Cramér's V: 0.0500
# ...
# Most contributing sanitation variable to health variables combined: cooking_fuel_source
# Mean Cramér's V: 0.11925710374555595

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Assuming you have loaded your dataset into a DataFrame named 'data'
# data = pd.read_csv('data.csv')

# List of sanitation variables and health variables
health_vars = ['hyp', 'mem_rel_dis', 'rheumatism', 'lung_dis', 'liver_dis', 'stomach_dis', 'self_com_on_health']
sanitation_vars = ['has_running_water', 'inhouse_shower_Bath', 'cooking_fuel_source', 'main_toilet_type', 'sewage_sys', 'road_type', 'waste_management']

# Create an empty DataFrame to store the Mean Cramér's V values and sanitation variables
result_df = pd.DataFrame(columns=['Sanitation Variable', 'Mean Cramér\'s V'])

# Create a dictionary to store aggregate Cramér's V values for each sanitation variable
aggregate_cramers = {}

# Loop through sanitation variables to calculate mean Cramér's V
for sanitation_var in sanitation_vars:
    aggregate_cramer = 0
    
    for health_var in health_vars:
        contingency_table = pd.crosstab(data[sanitation_var], data[health_var])
        cramer_v = cramers_v(contingency_table.values)
        aggregate_cramer += cramer_v
        
    # Calculate the mean Cramér's V across all health variables
    mean_cramer = aggregate_cramer / len(health_vars)
    
    # Store the mean Cramér's V in the dictionary
    aggregate_cramers[sanitation_var] = mean_cramer

# Populate the result DataFrame with sanitation variables and mean Cramér's V
for sanitation_var, mean_cramer in aggregate_cramers.items():
    result_df = result_df.append({'Sanitation Variable': sanitation_var, 'Mean Cramér\'s V': mean_cramer}, ignore_index=True)

# Display the result DataFrame
result_df.to_csv('./sanitation_meanCramerV.csv', index = False)

# Identify the sanitation variable with the highest mean Cramér's V
# most_contributing_variable = result_df.loc[result_df['Mean Cramér\'s V'].idxmax()]

# print("Most contributing sanitation variable to health variables combined:", most_contributing_variable['Sanitation Variable'])
# print("Mean Cramér's V:", most_contributing_variable['Mean Cramér\'s V'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1344\1873036064.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Sanitation Variable': sanitation_var, 'Mean Cramér\'s V': mean_cramer}, ignore_index=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_1344\1873036064.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Sanitation Variable': sanitation_var, 'Mean Cramér\'s V': mean_cramer}, ignore_index=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_1344\1873036064.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append({'Sanitation Variable': sanitation_var, 'Mean Cramér\'s V': mean_cramer}, ignore_index=True)
# ...

# %% [markdown]
# Binary Classification Model

# %% [markdown]
# Buiding the model

# %%
df_coded
# Out:
#      Year province    city  communityID  road_type  sewage_sys  \
# 0    2011     ±±¾©    ±±¾©       940041          3           1
# 1    2011     ±±¾©    ±±¾©       940041          3           1
# 2    2011     ±±¾©    ±±¾©       940041          3           1
# 3    2011     ±±¾©    ±±¾©       940041          3           1
# 4    2011     ±±¾©    ±±¾©       940041          3           1
# ..    ...      ...     ...          ...        ...         ...
# 616  2013   ËÄ´¨Ê¡  ÒË±öÊÐ       563022          3           1
# 617  2013   ËÄ´¨Ê¡  ÒË±öÊÐ       563022          3           1
# 618  2013   ËÄ´¨Ê¡  ÒË±öÊÐ       563022          3           1
# 619  2015   ËÄ´¨Ê¡  ÒË±öÊÐ       563022          3           1
# 620  2015   ËÄ´¨Ê¡  ÒË±öÊÐ       563022          3           1
#
#      main_toilet_type  cooking_fuel_source  has_running_water  \
# 0                   3                    5                  1
# 1                   3                    5                  1
# ...

# %% [markdown]
# 1. Health Status class prediction

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
scale = StandardScaler()

# %%
X_unscaled = df_coded[['road_type', 'sewage_sys', 'main_toilet_type', 'cooking_fuel_source', 'has_running_water', 'inhouse_shower_Bath','waste_management']]

X = scale.fit_transform(X_unscaled)
X
# Out:
# array([[ 0.39337708,  0.78293487, -0.12799792, ...,  0.64387777,
#          0.80366135,  0.49378636],
#        [ 0.39337708,  0.78293487, -0.12799792, ...,  0.64387777,
#          0.80366135,  0.49378636],
#        [ 0.39337708,  0.78293487, -0.12799792, ...,  0.64387777,
#          0.80366135,  0.49378636],
#        ...,
#        [ 0.39337708,  0.78293487,  1.03239202, ...,  0.64387777,
#          0.80366135, -1.90810393],
#        [ 0.39337708,  0.78293487,  1.03239202, ...,  0.64387777,
#         -1.08676932, -1.90810393],
#        [ 0.39337708,  0.78293487,  1.03239202, ...,  0.64387777,
#         -1.08676932, -1.90810393]])

# %%
y = df_coded["health_status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=1)

# %%
lr_logistic = LogisticRegression()
model_log = lr_logistic.fit(X_train,y_train)

# %%
y_test
# Out:
# 162    0
# 101    0
# 537    0
# 593    0
# 23     0
#       ..
# 435    1
# 314    0
# 495    0
# 262    0
# 277    0
# Name: health_status, Length: 94, dtype: int64

# %%
health_stat_pred = model_log.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report
accuracy = accuracy_score(health_stat_pred, y_test)
report = classification_report(health_stat_pred, y_test)
# print(report)
accuracy
# Out:
# 0.776595744680851

# %% [markdown]
# General Relationship Between Sanitation Infrastructures and Health Status Using health Score

# %%
df_coded["Health_score"] = df_coded[["stomach_dis", "liver_dis", "lung_dis", "rheumatism", "mem_rel_dis", "hyp", "self_com_on_health"]].sum(axis=1)	
min(df_coded.Health_score)
# Out:
# 1

# %% [markdown]
# The Score Ranges from 1-8: the lower the score, the better the health status of that resident

# %% [markdown]
# Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# %%
y = df_coded["Health_score"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=1)
lr = LinearRegression()
model_lr = lr.fit(X_train,y_train)
health_score_pred = model_lr.predict(X_test)
error = np.sqrt(mean_squared_error(health_score_pred, y_test))
print(f"rmse: {error}")
# Out:
# rmse: 1.5543096461063666

# %%
health_score_pred
# Out:
# array([4.24897186, 4.8222429 , 3.81753752, 4.73820954, 3.62255642,
#        4.32757042, 3.79064862, 4.21092387, 4.1649385 , 4.1868751 ,
#        3.991894  , 3.991894  , 4.1649385 , 4.24658861, 4.30382311,
#        4.32757042, 3.81753752, 4.6581263 , 4.6581263 , 3.79643747,
#        3.991894  , 3.9355989 , 4.05519416, 3.991894  , 4.8222429 ,
#        3.991894  , 4.14762371, 3.991894  , 3.91671723, 4.1649385 ,
#        3.99152715, 4.30988877, 3.91671723, 3.991894  , 4.1626581 ,
#        3.991894  , 4.03409411, 4.73599115, 4.8222429 , 4.36776694,
#        4.22548856, 3.92906354, 4.24970557, 4.0311454 , 4.36776694,
#        3.991894  , 3.991894  , 4.54117829, 4.22595826, 3.9355989 ,
#        3.991894  , 3.991894  , 3.991894  , 3.87541569, 4.0311454 ,
#        3.991894  , 3.93134394, 4.8222429 , 3.991894  , 4.36776694,
#        4.54117829, 4.21092387, 3.87541569, 3.99134372, 4.32492316,
#        4.32757042, 3.991894  , 3.93134394, 4.22281667, 3.93218049,
# ...

# %%
y_test
# Out:
# 162    6
# 101    3
# 537    6
# 593    7
# 23     3
#       ..
# 435    2
# 314    6
# 495    4
# 262    4
# 277    3
# Name: Health_score, Length: 94, dtype: int64

# %%
plt.scatter(y_test, health_score_pred)

# %% [markdown]
# Random Forest Regressor

# %%
y = df_coded["Health_score"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=1)
rf = RandomForestRegressor(random_state = 42)
model_rf = rf.fit(X_train,y_train)
health_score_pred = model_rf.predict(X_test)
error_rf = np.sqrt(mean_squared_error(y_test, health_score_pred))
print(f"rmse: {error_rf}")
# Out:
# rmse: 1.296452014451368

# %% [markdown]
# The RF in this case... We want to know the feature importance of that model

# %%
# Get the feature importances
feature_importance = model_rf.feature_importances_

# Create a DataFrame to show the feature importance scores along with their corresponding feature names
feature_importance_df = pd.DataFrame({'Feature': X_unscaled.columns, 'Importance': feature_importance})

# Sort the DataFrame by importance in descending order
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Print or visualize the feature importance scores
print(feature_importance_df)

# Optional: Plot a horizontal bar chart to visualize feature importance

plt.figure(figsize=(10, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'], color='g')
plt.xlabel('Importance Score')
plt.ylabel('Feature')
plt.title('Feature Importance of Random Forest Regressor Model')
plt.show()
# Out:
#                Feature  Importance
# 3  cooking_fuel_source    0.284844
# 2     main_toilet_type    0.209143
# 5  inhouse_shower_Bath    0.123664
# 6     waste_management    0.109805
# 1           sewage_sys    0.092985
# 4    has_running_water    0.092659
# 0            road_type    0.086901

# %% [markdown]
# in the absence of significant variable for random Forest model

# %%
X_no_cooking = X_unscaled.drop(columns=["cooking_fuel_source"])
X_no_cooking = scale.fit_transform(X_no_cooking)

# %%
y = df_coded["Health_score"]
X_train, X_test, y_train, y_test = train_test_split(X_no_cooking, y, test_size=0.15, random_state=1)
rf = RandomForestRegressor(random_state = 42)
model = rf.fit(X_train,y_train)
health_score_pred = model.predict(X_test)
error = np.sqrt(mean_squared_error(health_score_pred, y_test))
print(f"rmse: {error}")
# Out:
# rmse: 1.436556213695717

# %%
x = 0.955491062531849 - 0.9542479534384043
x
# Out:
# 0.0012431090934447164

# %% [markdown]
# Spearman Correlation between variables

# %%
plt.figure(figsize= (12, 6))
sns.heatmap(df_coded.corr(method='spearman'), annot= True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1344\2823881444.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_coded.corr(method='spearman'), annot= True)
# <Axes: >
